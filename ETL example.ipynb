# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

def extract()-> dict:
    """ This API extracts data from
    http://universities.hipolabs.com
    """
    API_URL = "http://universities.hipolabs.com/search?country=United+States"
    data = requests.get(API_URL).json()
    return data

# %% [markdown]
# ## Data Transformation

# %%
def transform(data:dict) -> pd.DataFrame:
    """ Transforms the dataset into desired structure"""
    df = pd.DataFrame(data)
    print(f"Total Number of universities from API {len(data)}")
    df['domains'] = [','.join(map(str, l)) for l in df['domains']]
    df['web_pages'] = [','.join(map(str, l)) for l in df['web_pages']]
    df = df.reset_index(drop=True)
    return df[["domains","country","web_pages","name"]]

def load(df:pd.DataFrame)-> None:
    """ Loads data into a sqllite database"""
    disk_engine = create_engine('sqlite:///my_lite_store.db')
    df.to_sql('cal_uni', disk_engine, if_exists='replace')

# %%
data = extract()
df = transform(data)
load(df)
# Out:
# Total Number of universities from API 4535

# %%
df.head()
# Out:
#           domains        country                   web_pages  \
# 0    marywood.edu  United States     http://www.marywood.edu
# 1  lindenwood.edu  United States  http://www.lindenwood.edu/
# 2    sullivan.edu  United States       https://sullivan.edu/
# 3        fscj.edu  United States       https://www.fscj.edu/
# 4      xavier.edu  United States     https://www.xavier.edu/
#
#                                     name
# 0                    Marywood University
# 1                  Lindenwood University
# 2                    Sullivan University
# 3  Florida State College at Jacksonville
# 4                      Xavier University

# %% [markdown]
# ## Another Method

# %%
from sqlite3 import connect
connection = connect('Database.db')
curr = connection.cursor()
curr.execute('CREATE TABLE IF NOT EXISTS University_data (domain TEXT, country TEXT, Webpade TEXT, name TEXT)')
# write the dataframe into the database table  
df.to_sql('University_data', connection, if_exists='replace')
curr.execute('''SELECT * FROM University_data''')
curr.execute('SELECT * FROM University_data')
data = curr.fetchmany(100)

# %%
data
# Out:
# [(0,
#   'marywood.edu',
#   'United States',
#   'http://www.marywood.edu',
#   'Marywood University'),
#  (1,
#   'lindenwood.edu',
#   'United States',
#   'http://www.lindenwood.edu/',
#   'Lindenwood University'),
#  (2,
#   'sullivan.edu',
#   'United States',
#   'https://sullivan.edu/',
#   'Sullivan University'),
#  (3,
#   'fscj.edu',
#   'United States',
#   'https://www.fscj.edu/',
#   'Florida State College at Jacksonville'),
#  (4,
#   'xavier.edu',
#   'United States',
#   'https://www.xavier.edu/',
#   'Xavier University'),
#  (5,
#   'tusculum.edu',
#   'United States',
#   'https://home.tusculum.edu/',
#   'Tusculum College'),
#  (6,
#   'cst.edu',
#   'United States',
#   'https://cst.edu/',
#   'Claremont School of Theology'),
#  (7,
#   'columbiasc.edu',
#   'United States',
#   'https://www.columbiasc.edu/',
#   'Columbia College (SC)'),
#  (8,
#   'clpccd.edu',
#   'United States',
#   'http://www.clpccd.edu/',
#   'Chabot-Las Positas Community College District'),
#  (9,
#   'keller.edu',
#   'United States',
#   'https://www.keller.edu/',
#   'Keller Graduate School of Management'),
#  (10,
#   'monroecollege.edu',
#   'United States',
#   'https://monroecollege.edu/',
#   'Monroe College'),
#  (11,
#   'smccd.edu',
#   'United States',
#   'https://smccd.edu/',
#   'San Mateo County Community College District'),
#  (12,
#   'losrios.edu',
#   'United States',
#   'http://losrios.edu/',
#   'Los Rios Community College District'),
#  (13,
#   'digipen.edu',
#   'United States',
#   'https://www.digipen.edu/',
#   'DigiPen Institute of Technology'),
#  (14,
#   'upmc.edu,upmc.com',
#   'United States',
#   'https://www.upmc.com/',
#   'University of Pittsburgh Medical Center'),
#  (15,
#   'cgu.edu',
#   'United States',
#   'https://www.cgu.edu/',
#   'Claremont Graduate University'),
#  (16,
#   'utrgv.edu',
#   'United States',
#   'http://www.utrgv.edu/',
#   'University of Texas Rio Grande Valley'),
#  (17,
#   'mountsaintvincent.edu',
#   'United States',
#   'https://mountsaintvincent.edu/',
#   'College of Mount Saint Vincent'),
#  (18,
#   'uasys.edu',
#   'United States',
#   'https://www.uasys.edu/',
#   'University of Arkansas System eVersity'),
#  (19, 'ecpi.edu', 'United States', 'https://www.ecpi.edu/', 'ECPI University'),
#  (20,
#   'umw.edu',
#   'United States',
#   'https://www.umw.edu/',
#   'University of Mary Washington'),
#  (21,
#   'bw.edu',
#   'United States',
#   'https://www.bw.edu/',
#   'Baldwin Wallace University'),
#  (22,
#   'csuci.edu',
#   'United States',
#   'https://www.csuci.edu/',
#   'California State University Channel Islands'),
#  (23,
#   'brandman.edu',
#   'United States',
#   'https://www.brandman.edu/',
#   'Brandman University'),
#  (24,
#   'uscga.edu',
#   'United States',
#   'http://www.uscga.edu/',
#   'United States Coast Guard Academy'),
#  (25,
#   'athens.edu',
#   'United States',
#   'http://www.athens.edu/',
#   'Athens State University'),
#  (26,
#   'scripps.edu',
#   'United States',
#   'https://scripps.edu/',
#   'The Scripps Research Institute'),
#  (27,
#   'easternflorida.edu',
#   'United States',
#   'http://www.easternflorida.edu/',
#   'Eastern Florida State College'),
#  (28,
#   'wne.edu',
#   'United States',
#   'http://www1.wne.edu/',
#   'Western New England University'),
#  (29, 'king.edu', 'United States', 'https://king.edu/', 'King University'),
#  (30,
#   'ggc.edu',
#   'United States',
#   'https://ggc.edu/',
#   'Georgia Gwinnett College'),
#  (31,
#   'trident.edu',
#   'United States',
#   'https://www.trident.edu/',
#   'Trident University'),
#  (32,
#   'alliant.edu',
#   'United States',
#   'https://www.alliant.edu/',
#   'Alliant International University'),
#  (33,
#   'mvsu.edu',
#   'United States',
#   'https://mvsu.edu/',
#   'Mississippi Valley State University'),
#  (34,
#   'roosevelt.edu',
#   'United States',
#   'https://www.roosevelt.edu/',
#   'Roosevelt University'),
#  (35,
#   'itt-tech.info,itt-tech.edu',
#   'United States',
#   'http://itt-tech.info/',
#   'ITT Technical Institute'),
#  (36,
#   'iecc.edu',
#   'United States',
#   'https://iecc.edu/',
#   'Illinois Eastern Community Colleges'),
#  (37, 'park.edu', 'United States', 'https://park.edu/', 'Park University'),
#  (38,
#   'mssm.edu',
#   'United States',
#   'http://icahn.mssm.edu/',
#   'Icahn School of Medicine at Mount Sinai'),
#  (39, 'uvu.edu', 'United States', 'https://uvu.edu/', 'Utah Valley Uniersity'),
#  (40,
#   'wlc.edu',
#   'United States',
#   'http://www.wlc.edu/',
#   'Wisconsin Lutheran College'),
#  (41,
#   'rccd.edu',
#   'United States',
#   'http://www.rccd.edu/',
#   'Riverside Community College District'),
#  (42,
#   'wakehealth.edu',
#   'United States',
#   'http://www.wakehealth.edu/',
#   'Wake Forest Baptist Health'),
#  (43,
#   'umb.edu',
#   'United States',
#   'https://www.umb.edu/',
#   'University of Massachusetts Boston'),
#  (44,
#   'floridapoly.edu',
#   'United States',
#   'https://floridapoly.edu/',
#   'Florida Polytechnic University'),
#  (45, 'wagner.edu', 'United States', 'https://wagner.edu/', 'Wagner College'),
#  (46,
#   'wilmu.edu',
#   'United States',
#   'https://www.wilmu.edu/',
#   'Wilmington University'),
#  (47,
#   'itu.edu',
#   'United States',
#   'https://itu.edu/',
#   'International Technological University'),
#  (48,
#   'yhc.edu',
#   'United States',
#   'https://www.yhc.edu/',
#   'Young Harris College'),
#  (49,
#   'findlay.edu',
#   'United States',
#   'https://www.findlay.edu/',
#   'University of Findlay'),
#  (50,
#   'pcom.edu',
#   'United States',
#   'https://www.pcom.edu/',
#   'Philadelphia College of Osteopathic Medicine'),
#  (51,
#   'yosemite.edu',
#   'United States',
#   'https://www.yosemite.edu/',
#   'Yosemite Community College District'),
#  (52,
#   'coastalalabama.edu',
#   'United States',
#   'http://www.coastalalabama.edu/',
#   'Coastal Alabama Community College'),
#  (53,
#   'pnw.edu',
#   'United States',
#   'https://www.pnw.edu/',
#   'Purdue University Northwest'),
#  (54,
#   'columbiabasin.edu',
#   'United States',
#   'http://www.columbiabasin.edu/',
#   'Columbia Basin College'),
#  (55,
#   'seattlecolleges.edu',
#   'United States',
#   'https://www.seattlecolleges.edu/',
#   'Seattle Colleges'),
#  (56,
#   'lipscomb.edu',
#   'United States',
#   'https://www.lipscomb.edu/',
#   'Lipscomb University'),
#  (57,
#   'tiffin.edu',
#   'United States',
#   'http://www.tiffin.edu/',
#   'Tiffin University'),
#  (58, 'troy.edu', 'United States', 'https://troy.edu/', 'Troy University'),
#  (59, 'student.42.us.org', 'United States', 'http://www.42.us.org/', '42 US'),
#  (60,
#   'calbaptist.edu',
#   'United States',
#   'http://www.calbaptist.edu/',
#   'California Baptist University'),
#  (61,
#   'stevenson.edu',
#   'United States',
#   'http://www.stevenson.edu/',
#   'Stevenson University'),
#  (62,
#   'mbl.edu',
#   'United States',
#   'http://www.mbl.edu/',
#   'Marine Biological Laboratory'),
#  (63,
#   'maryville.edu',
#   'United States',
#   'http://www.maryville.edu/',
#   'Maryville University'),
#  (64, 'aii.edu', 'United States', 'http://www.aii.edu/', 'The Art Institutes'),
#  (65,
#   'umc.edu',
#   'United States',
#   'http://www.umc.edu/',
#   'University of Mississippi Medical Center'),
#  (66,
#   'uco.edu',
#   'United States',
#   'http://www.uco.edu/',
#   'University of Central Oklahoma'),
#  (67,
#   'hallmarkuniversity.edu',
#   'United States',
#   'http://www.hallmarkuniversity.edu/',
#   'Hallmark University'),
#  (68,
#   'keiseruniversity.edu',
#   'United States',
#   'http://www.keiseruniversity.edu/',
#   'Keiser University'),
#  (69,
#   'sjrstate.edu',
#   'United States',
#   'http://www.sjrstate.edu/',
#   'St. Johns River State College'),
#  (70,
#   'irsc.edu',
#   'United States',
#   'http://www.irsc.edu/',
#   'Indian River State College'),
#  (71,
#   'barnard.edu',
#   'United States',
#   'http://www.barnard.edu/',
#   'Barnard College'),
#  (72,
#   'calsouthern.edu',
#   'United States',
#   'http://www.calsouthern.edu/',
#   'California Southern University'),
#  (73,
#   'laverne.edu',
#   'United States',
#   'http://www.laverne.edu/',
#   'University of La Verne'),
#  (74,
#   'washjeff.edu',
#   'United States',
#   'http://www.washjeff.edu/',
#   'Washington & Jefferson College'),
#  (75,
#   'uopeople.edu',
#   'United States',
#   'http://www.uopeople.edu/',
#   'University of the People'),
#  (76, 'touro.edu', 'United States', 'http://www.touro.edu/', 'Touro College'),
#  (77,
#   'njcu.edu',
#   'United States',
#   'http://www.njcu.edu/',
#   'New Jersey City University'),
#  (78,
#   'lander.edu',
#   'United States',
#   'http://www.lander.edu/',
#   'Lander University'),
#  (79,
#   'sunymaritime.edu',
#   'United States',
#   'http://www.sunymaritime.edu/',
#   'SUNY Maritime College'),
#  (80,
#   'lesley.edu',
#   'United States',
#   'http://www.lesley.edu/',
#   'Lesley University'),
#  (81,
#   'lauruscollege.edu',
#   'United States',
#   'http://www.lauruscollege.edu/',
#   'Laurus College'),
#  (82,
#   'np.edu',
#   'United States',
#   'http://www.np.edu/',
#   'National Park College'),
#  (83,
#   'oc.edu',
#   'United States',
#   'http://www.oc.edu/',
#   'Oklahoma Christian University'),
#  (84,
#   'sdcc.edu',
#   'United States',
#   'http://www.sdcc.edu/',
#   'San Diego Christian College'),
#  (85,
#   'sans.edu',
#   'United States',
#   'http://www.sans.edu/',
#   'SANS Technology Institute'),
#  (86,
#   'phsc.edu',
#   'United States',
#   'http://www.phsc.edu/',
#   'Pasco-Hernando State College'),
#  (87,
#   'ncf.edu',
#   'United States',
#   'http://www.ncf.edu/',
#   'New College of Florida'),
#  (88,
#   'gcu.edu',
#   'United States',
#   'http://www.gcu.edu/',
#   'Grand Canyon University'),
#  (89,
#   'cshl.edu',
#   'United States',
#   'http://www.cshl.edu/',
#   'Cold Spring Harbor Laboratory'),
#  (90,
#   'asurams.edu',
#   'United States',
#   'http://www.asurams.edu/',
#   'Albany State University'),
#  (91,
#   'lasell.edu',
#   'United States',
#   'http://www.lasell.edu/',
#   'Lasell College'),
#  (92,
#   '4cd.edu',
#   'United States',
#   'http://www.4cd.edu/',
#   'Contra Costa Community College District'),
#  (93,
#   'msmary.edu',
#   'United States',
#   'http://www.msmary.edu/',
#   "Mount St. Mary's University"),
#  (94,
#   'robertmorris.edu',
#   'United States',
#   'http://www.robertmorris.edu/',
#   'Robert Morris University Illinois'),
#  (95,
#   'nwfsc.edu',
#   'United States',
#   'http://www.nwfsc.edu/',
#   'Northwest Florida State College'),
#  (96,
#   'wvwc.edu',
#   'United States',
#   'http://www.wvwc.edu/',
#   'West Virginia Wesleyan College'),
#  (97, 'utica.edu', 'United States', 'http://www.utica.edu/', 'Utica College'),
#  (98,
#   'ccnn.edu',
#   'United States',
#   'http://www.ccnn.edu/',
#   'Career College of Northern Nevada'),
#  (99,
#   'csn.edu',
#   'United States',
#   'https://www.csn.edu/',
#   'College of Southern Nevada')]
